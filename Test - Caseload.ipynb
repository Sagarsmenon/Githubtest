# %%
import pandas as pd
data =pd.read_csv(r"C:\Users\smenon\Documents\Python Scripts\caseload_test01.csv")
new_data = data[(data["Owner Team"]=="NEOFACS Adoption") | (data["Owner Team"]=="NEOFACS Child Care North") | 
                (data["Owner Team"]=="NEOFACS Child Care Central") |
                (data["Owner Team"]=="NEOFACS Child Care South") | (data["Owner Team"]=="NEOFACS Protection Central 1") | 
                (data["Owner Team"]=="NEOFACS Protection Central 2") | (data["Owner Team"]=="NEOFACS Protection Central 3") |
                (data["Owner Team"]=="NEOFACS Protection Central 4") | (data["Owner Team"]=="NEOFACS Protection North 1") | 
                (data["Owner Team"]=="NEOFACS Protection North 2") | (data["Owner Team"]=="NEOFACS Protection North 3") |
                (data["Owner Team"]=="NEOFACS Protection South 1") | (data["Owner Team"]=="NEOFACS Protection South 2") |
                (data["Owner Team"]=="NEOFACS Protection South 3") | (data["Owner Team"]=="NEOFACS Resource Central and South") |
                (data["Owner Team"]=="NEOFACS Resource North")]

#new_data["Worker_name"] = new_data["Owner Last Name"].astype(str)+' ' + new_data["Owner First Name"]
#new_data = new_data[data["Case Type"]!= "Screening Case"]
duplicate = data[data.duplicated("Person Reference #")]
print(duplicate)

#new_data.to_csv(r"C:\Users\smenon\Documents\Python Scripts\test01.csv", index=False)
# Out:
#                        Owner Team  Team Supervisor Supervisor Last Name  \
# 22             NEOFACS Disclosure     Suzanna Bala                 Bala
# 154  NEOFACS Protection Central 2  Jessica Daschuk              Daschuk
# 156  NEOFACS Protection Central 2  Jessica Daschuk              Daschuk
# 163  NEOFACS Protection Central 2  Jessica Daschuk              Daschuk
# 165  NEOFACS Protection Central 2  Jessica Daschuk              Daschuk
# ..                            ...              ...                  ...
# 829  NEOFACS Protection Central 1     Laura Yuskow               Yuskow
# 835  NEOFACS Protection Central 1     Laura Yuskow               Yuskow
# 845  NEOFACS Protection Central 1     Laura Yuskow               Yuskow
# 848  NEOFACS Protection Central 1     Laura Yuskow               Yuskow
# 849  NEOFACS Protection Central 1     Laura Yuskow               Yuskow
#
#     Supervisor First Name Owner Last Name Owner First Name  \
# ...

# %%
# Out:
#             Owner Team Team Supervisor Supervisor Last Name  \
# 0   NEOFACS Disclosure    Suzanna Bala                 Bala
# 1   NEOFACS Disclosure    Suzanna Bala                 Bala
# 2   NEOFACS Disclosure    Suzanna Bala                 Bala
# 3   NEOFACS Disclosure    Suzanna Bala                 Bala
# 4   NEOFACS Disclosure    Suzanna Bala                 Bala
# 5   NEOFACS Disclosure    Suzanna Bala                 Bala
# 6   NEOFACS Disclosure    Suzanna Bala                 Bala
# 7   NEOFACS Disclosure    Suzanna Bala                 Bala
# 8   NEOFACS Disclosure    Suzanna Bala                 Bala
# 9   NEOFACS Disclosure    Suzanna Bala                 Bala
# 10  NEOFACS Disclosure    Suzanna Bala                 Bala
# 11  NEOFACS Disclosure    Suzanna Bala                 Bala
# 12  NEOFACS Disclosure    Suzanna Bala                 Bala
# 13  NEOFACS Disclosure    Suzanna Bala                 Bala
# 14  NEOFACS Disclosure    Suzanna Bala                 Bala
# ...
